# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
f="./datos/rake03.0H.log"
rake=pd.read_csv(f, index_col="nodenumber")

# %%
pd.options.display.float_format = '{:.10f}'.format #Quitar la notación científica y mostrar 10 decimales

# %%
#rake.dtypes  #Verificar que las columnas sean de tipo numérico
#rake.columns #Verificar que encabezados sean "object"

# %%
rake["Velfricc"]=3
rake["Velfricc2"]=3
rake["Velfricc3"]=rake.Velfricc+rake.Velfricc2

# %%
rake
# Out:
#                 x-coordinate      y-coordinate      z-coordinate  \
# nodenumber
# 1               0.0000000000      0.0000000000      0.0000000000
# 2              -0.0000000000      0.0100719426      0.0000000000
# 3              -0.0000000000      0.0201438848      0.0000000000
# 4              -0.0000000000      0.0302158278      0.0000000000
# 5              -0.0000000000      0.0402877709      0.0000000000
# ...                      ...               ...               ...
# 696             0.1000000000      1.3597122790     -0.0000000000
# 697             0.1000000000      1.3697841470     -0.0000000000
# 698             0.1000000000      1.3798561390     -0.0000000000
# 699             0.1000000000      1.3899281260     -0.0000000000
# 700             0.1000000000      1.4000000000      0.0000000000
#
#                     pressure  pressure-coefficient  dynamic-pressure  \
# nodenumber
# 1               0.4090359653          0.0119938572      0.0245696115
# ...

# %%
rake['pressure'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\WPy64-31050\python-3.10.5.amd64\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# C:\WPy64-31050\python-3.10.5.amd64\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\WPy64-31050\python-3.10.5.amd64\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pressure'
#
# The above exception was the direct cause of the following exception:
#
# ...
